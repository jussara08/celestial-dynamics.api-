# %%
import os
api_key = os.getenv("YZGZauuXi39Vp2rYg2SB5hrgi9ZRkrXgdSU6ItsZ")
api_key = os.getenv("API_KEY")  
print(api_key)
# Out:
# None

# %%
API_KEY='YZGZauuXi39Vp2rYg2SB5hrgi9ZRkrXgdSU6ItsZ'
# %pip install python-dotenv

from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("api_key")
print("YZGZauuXi39Vp2rYg2SB5hrgi9ZRkrXgdSU6ItsZ")
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# YZGZauuXi39Vp2rYg2SB5hrgi9ZRkrXgdSU6ItsZ

# %%
from dotenv import find_dotenv, load_dotenv
import os

load_dotenv(find_dotenv())
print(os.environ['API_KEY'])
# Out:
# YZGZauuXi39Vp2rYg2SB5hrgi9ZRkrXgdSU6ItsZ

# %% [markdown]
# NASA NEO (Asteroids)

# %%
import requests
import os
from dotenv import load_dotenv

load_dotenv()
API_KEY='YZGZauuXi39Vp2rYg2SB5hrgi9ZRkrXgdSU6ItsZ'
api_key = os.getenv("API_KEY")

url = "https://api.nasa.gov/neo/rest/v1/feed" 


headers = {
    "Authorization": f"Bearer {api_key}"
}

url = "https://api.nasa.gov/neo/rest/v1/feed"

params = {
    "api_key": api_key
}

response = requests.get(url, params=params)

print("Status:", response.status_code)
print("Response JSON:")


params = {
    "api_key": api_key
}

response = requests.get(url, params=params)

print("Status:", response.status_code)
print("Response JSON:")
# Out:
# Status: 200
# Response JSON:
# Status: 200
# Response JSON:

# %%
response= requests.get('https://api.nasa.gov/DONKI/CME?startDate=2017-01-03&endDate=2017-01-03&api_key=DEMO_KEY')
response
# Out:
# <Response [200]>

# %%
response.content
response.json()
# Out:
# [{'activityID': '2017-01-03T03:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2017-01-03T03:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'The CME has two stages, the first starting at 03:12Z and the second at 06:00Z. The second stage merges with the first stage and that is what is measured. The source is a small off limb eruption in the SE of SDO AIA 171 between 01:55Z and 02:43Z.',
#   'submissionTime': '2017-01-03T19:40Z',
#   'versionId': 2,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/12056/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2017-01-03T13:08Z',
#     'latitude': -10.0,
#     'longitude': -105.0,
#     'halfAngle': 20.0,
#     'speed': 645.0,
#     'type': 'C',
#     'featureCode': 'null',
#     'imageType': None,
#     'measurementTechnique': 'null',
# ...

# %% [markdown]
# NASA NEO (Asteroids)

# %%
url = "https://api.nasa.gov/neo/rest/v1/feed"
params = {
    "api_key": api_key,
    "count": 10
}

response = requests.get(url, params=params)
data = response.json()

df = pd.json_normalize(data)
df.head()

data = response.json()
import pandas as pd

df = pd.json_normalize(data)
df.head(10)
# Out:
#    element_count                                         links.next  \
# 0             90  http://api.nasa.gov/neo/rest/v1/feed?start_dat...
#
#                                       links.previous  \
# 0  http://api.nasa.gov/neo/rest/v1/feed?start_dat...
#
#                                           links.self  \
# 0  http://api.nasa.gov/neo/rest/v1/feed?start_dat...
#
#                        near_earth_objects.2025-11-26  \
# 0  [{'links': {'self': 'http://api.nasa.gov/neo/r...
#
#                        near_earth_objects.2025-11-25  \
# 0  [{'links': {'self': 'http://api.nasa.gov/neo/r...
#
#                        near_earth_objects.2025-11-28  \
# 0  [{'links': {'self': 'http://api.nasa.gov/neo/r...
#
#                        near_earth_objects.2025-11-27  \
# 0  [{'links': {'self': 'http://api.nasa.gov/neo/r...
#
#                        near_earth_objects.2025-12-01  \
# 0  [{'links': {'self': 'http://api.nasa.gov/neo/r...
#
# ...

# %%
data = response.json()

# %%
import pandas as pd

df = pd.json_normalize(data)
df.head(10)
# Out:
#    element_count                                         links.next  \
# 0             90  http://api.nasa.gov/neo/rest/v1/feed?start_dat...
#
#                                       links.previous  \
# 0  http://api.nasa.gov/neo/rest/v1/feed?start_dat...
#
#                                           links.self  \
# 0  http://api.nasa.gov/neo/rest/v1/feed?start_dat...
#
#                        near_earth_objects.2025-11-26  \
# 0  [{'links': {'self': 'http://api.nasa.gov/neo/r...
#
#                        near_earth_objects.2025-11-25  \
# 0  [{'links': {'self': 'http://api.nasa.gov/neo/r...
#
#                        near_earth_objects.2025-11-28  \
# 0  [{'links': {'self': 'http://api.nasa.gov/neo/r...
#
#                        near_earth_objects.2025-11-27  \
# 0  [{'links': {'self': 'http://api.nasa.gov/neo/r...
#
#                        near_earth_objects.2025-12-01  \
# 0  [{'links': {'self': 'http://api.nasa.gov/neo/r...
#
# ...

# %%
import requests
import pandas as pd
import datetime as dt
import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("API_KEY")

all_rows = []

for i in range(90):   #
    date = dt.date.today() - dt.timedelta(days=i)
    date_str = date.strftime("%Y-%m-%d")

    url = f"https://api.nasa.gov/neo/rest/v1/feed"
    params = {
        "start_date": date_str,
        "end_date": date_str,
        "api_key": api_key
    }

    response = requests.get(url, params=params)
    data = response.json()

    for ast in data["near_earth_objects"][date_str]:
        row = {
            "name": ast["name"],
            "id": ast["id"],
            "hazardous": ast["is_potentially_hazardous_asteroid"],
            "close_approach_date": date_str,
            "miss_distance_km": ast["close_approach_data"][0]["miss_distance"]["kilometers"],
            "relative_velocity_km_s": ast["close_approach_data"][0]["relative_velocity"]["kilometers_per_second"],
            "diameter_min_m": ast["estimated_diameter"]["meters"]["estimated_diameter_min"],
            "diameter_max_m": ast["estimated_diameter"]["meters"]["estimated_diameter_max"]
        }
        all_rows.append(row)

df = pd.DataFrame(all_rows)
df.to_csv("neo_90days.csv", index=False)

df.head(50)
# Out:
#                  name        id  hazardous close_approach_date  \
# 0         (2017 HS49)   3774381      False          2025-11-29
# 1           (2018 YH)   3836942       True          2025-11-29
# 2          (2019 UY1)   3879278      False          2025-11-29
# 3         (2021 GL16)  54137806      False          2025-11-29
# 4          (2021 WG1)  54224162      False          2025-11-29
# 5          (2021 XF6)  54230081      False          2025-11-29
# 6         (2022 UV15)  54321820      False          2025-11-29
# 7          (2022 WK6)  54329631      False          2025-11-29
# 8          (2022 WK9)  54330575      False          2025-11-29
# 9         (2025 SX21)  54549108      False          2025-11-29
# 10        (2025 TH14)  54554064      False          2025-11-29
# 11         (2025 VL9)  54562370      False          2025-11-29
# 12         (2025 WB3)  54563250      False          2025-11-29
# 13         (2025 WQ3)  54563266      False          2025-11-29
# ...

# %%
df.shape
# Out:
# (1718, 8)

# %% [markdown]
# DONKI Solar Flares (FLR)

# %%
import requests
import os
from dotenv import load_dotenv

load_dotenv()
API_KEY='YZGZauuXi39Vp2rYg2SB5hrgi9ZRkrXgdSU6ItsZ'
api_key = os.getenv("API_KEY")

url = " https://api.nasa.gov/DONKI/FLR" 


headers = {
    "Authorization": f"Bearer {api_key}"
}

url = "https://api.nasa.gov/DONKI/FLR"

params = {
    "api_key": api_key
}

response = requests.get(url, params=params)

print("Status:", response.status_code)
print("Response JSON:")


params = {
    "api_key": api_key
}

response = requests.get(url, params=params)

print("Status:", response.status_code)
print("Response JSON:")
# Out:
# Status: 200
# Response JSON:
# Status: 200
# Response JSON:

# %%
import pandas as pd
url = "https://api.nasa.gov/DONKI/FLR"
params = {
    "api_key": api_key,
    "count": 10
}

response = requests.get(url, params=params)
data = response.json()

df = pd.json_normalize(data)
df.head()

data = response.json()
import pandas as pd

df = pd.json_normalize(data)

params = {
    "api_key": api_key,
    "count": 10
}

response = requests.get(url, params=params)
data = response.json()

df = pd.json_normalize(data)
df.head()

data = response.json()
import pandas as pd

df = pd.json_normalize(data)

df.to_csv("donki_solar_flares.csv", index=False)

# %%
df.head(50)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   flrID              34 non-null     object
#  1   catalog            34 non-null     object
#  2   instruments        34 non-null     object
#  3   beginTime          34 non-null     object
#  4   peakTime           34 non-null     object
#  5   endTime            34 non-null     object
#  6   classType          34 non-null     object
#  7   sourceLocation     34 non-null     object
#  8   activeRegionNum    33 non-null     float64
#  9   note               34 non-null     object
#  10  submissionTime     34 non-null     object
#  11  versionId          34 non-null     int64
#  12  link               34 non-null     object
#  13  linkedEvents       23 non-null     object
#  14  sentNotifications  9 non-null      object
# dtypes: float64(1), int64(1), object(13)
# ...

# %%
import pandas as pd

df = pd.json_normalize(data)

df["instrument"] = df["instruments"].apply(
    lambda x: x[0]["displayName"] if isinstance(x, list) and len(x) > 0 else None
)


cols_to_drop = [
    "instruments",
    "linkedEvents",
    "messageType",
    "messageID",
    "messageURL",
]
df = df.drop(columns=[c for c in cols_to_drop if c in df.columns], errors="ignore")


time_cols = ["beginTime", "peakTime", "endTime"]

for col in time_cols:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col], errors="coerce")


df["classType"] = df["classType"].astype(str).str.strip()
df["catalog"] = df["catalog"].astype(str).str.strip()


order = [
    "flrID",
    "classType",
    "instrument",
    "sourceLocation",
    "catalog",
    "beginTime",
    "peakTime",
    "endTime",
]
df = df[[col for col in order if col in df.columns]]


df.head(20)
# Out:
#                           flrID classType            instrument  \
# 0   2025-10-31T19:18:00-FLR-001      C7.1  GOES-P: EXIS 1.0-8.0
# 1   2025-11-02T00:13:00-FLR-001      M1.0  GOES-P: EXIS 1.0-8.0
# 2   2025-11-02T12:33:00-FLR-001      C8.2  GOES-P: EXIS 1.0-8.0
# 3   2025-11-03T03:56:00-FLR-001      C7.1  GOES-P: EXIS 1.0-8.0
# 4   2025-11-03T08:41:00-FLR-001      M1.6  GOES-P: EXIS 1.0-8.0
# 5   2025-11-03T09:38:00-FLR-001      M5.0  GOES-P: EXIS 1.0-8.0
# 6   2025-11-03T12:19:00-FLR-001      M2.9  GOES-P: EXIS 1.0-8.0
# 7   2025-11-03T12:37:00-FLR-001      M3.2  GOES-P: EXIS 1.0-8.0
# 8   2025-11-03T17:04:00-FLR-001      M1.5  GOES-P: EXIS 1.0-8.0
# 9   2025-11-03T23:37:00-FLR-001      C8.7  GOES-P: EXIS 1.0-8.0
# 10  2025-11-04T01:31:00-FLR-001      M3.5  GOES-P: EXIS 1.0-8.0
# 11  2025-11-04T10:02:00-FLR-001      C4.6  GOES-P: EXIS 1.0-8.0
# 12  2025-11-04T17:15:00-FLR-001      X1.8  GOES-P: EXIS 1.0-8.0
# 13  2025-11-04T21:45:00-FLR-001      X1.1  GOES-P: EXIS 1.0-8.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('/Users/jussaragaspar/Downloads/donki_solar_flares.csv')

numeric_cols = df.select_dtypes(include='number').columns
col = numeric_cols[0]

y = df[col].dropna().values
x = np.arange(len(y))

m, b = np.polyfit(x, y, 1)
trend = m * x + b

plt.figure()
plt.plot(x, y, label="Data")
plt.plot(x, trend, linestyle="--", label="Trend")
plt.xlabel("Index")
plt.ylabel(col)
plt.title(f"Trend for {col}")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# DONKI(GEOMAGNETIC_STORMS)

# %%
import requests
import os
from dotenv import load_dotenv

load_dotenv()
API_KEY='YZGZauuXi39Vp2rYg2SB5hrgi9ZRkrXgdSU6ItsZ'
api_key = os.getenv("API_KEY")

url = "https://api.nasa.gov/DONKI/GST?startDate=2020-01-01&endDate=2025-01-01&api_key="+'YZGZauuXi39Vp2rYg2SB5hrgi9ZRkrXgdSU6ItsZ'


headers = {
    "Authorization": f"Bearer {api_key}"
}

url = "https://api.nasa.gov/DONKI/GST?startDate=2020-01-01&endDate=2025-01-01&api_key="+'YZGZauuXi39Vp2rYg2SB5hrgi9ZRkrXgdSU6ItsZ'

params = {
    "api_key": api_key
}

response = requests.get(url, params=params)

print("Status:", response.status_code)
print("Response JSON:")


params = {
    "api_key": api_key
}

response = requests.get(url, params=params)

print("Status:", response.status_code)
print("Response JSON:")
import pandas as pd
url = "https://api.nasa.gov/DONKI/GST?startDate=2020-01-01&endDate=2025-01-01&api_key="+'YZGZauuXi39Vp2rYg2SB5hrgi9ZRkrXgdSU6ItsZ'
params = {
    "api_key": api_key,
    "count": 10
}

response = requests.get(url, params=params)
data = response.json()

df = pd.json_normalize(data)
df.head()

data = response.json()
import pandas as pd

df = pd.json_normalize(data)

params = {
    "api_key": api_key,
    "count": 10
}

response = requests.get(url, params=params)
data = response.json()

df = pd.json_normalize(data)
df.head()

data = response.json()
import pandas as pd

df = pd.json_normalize(data)


params = {
    "api_key": api_key,
    "count": 10
}

response = requests.get(url, params=params)
data = response.json()

df = pd.json_normalize(data)
df.head()

data = response.json()
import pandas as pd

df = pd.json_normalize(data)

params = {
    "api_key": api_key,
    "count": 10
}

response = requests.get(url, params=params)
data = response.json()

df = pd.json_normalize(data)
df.head()

data = response.json()
import pandas as pd

df = pd.json_normalize(data)

df.to_csv("donki_geomagnetic_storm.csv", index=False)
# Out:
# Status: 200
# Response JSON:
# Status: 200
# Response JSON:

# %%
import requests
import pandas as pd
API_KEY='YZGZauuXi39Vp2rYg2SB5hrgi9ZRkrXgdSU6ItsZ'
url = "https://api.nasa.gov/DONKI/GST?startDate=2020-01-01&endDate=2025-01-01&api_key=" + API_KEY
params = {
    "api_key": api_key,
    "count": 10
}

data = response.json()

df = pd.json_normalize(data)
df.head()

data = response.json()
import pandas as pd

df = pd.json_normalize(data)

params = {
    "api_key": api_key,
    "count": 10
}


data = response.json()

df = pd.json_normalize(data)
df.head()

data = response.json()
import pandas as pd

df = pd.json_normalize(data)


params = {
    "api_key": api_key,
    "count": 10
}
url="https://api.nasa.gov/DONKI/GST?startDate=2020-01-01&endDate=2025-01-01&api_key=" + API_KEY
response = requests.get(url, params=params)
data = response.json()

df = pd.json_normalize(data)
df.head()

data = response.json()
import pandas as pd

df = pd.json_normalize(data)

params = {
    "api_key": api_key,
    "count": 10
}

response = requests.get(url, params=params)
data = response.json()

df = pd.json_normalize(data)
df.head()

data = response.json()
import pandas as pd

df = pd.json_normalize(data)

df.to_csv("donki_geomagnetic_storm.csv", index=False)

# %%
df.head(30)
# Out:
#                           gstID          startTime  \
# 0   2020-09-27T21:00:00-GST-001  2020-09-27T21:00Z
# 1   2021-03-01T03:00:00-GST-001  2021-03-01T03:00Z
# 2   2021-03-20T06:00:00-GST-001  2021-03-20T06:00Z
# 3   2021-05-12T12:00:00-GST-001  2021-05-12T12:00Z
# 4   2021-10-12T03:00:00-GST-001  2021-10-12T03:00Z
# 5   2021-11-03T21:00:00-GST-001  2021-11-03T21:00Z
# 6   2022-01-14T21:00:00-GST-001  2022-01-14T21:00Z
# 7   2022-01-19T00:00:00-GST-001  2022-01-19T00:00Z
# 8   2022-02-03T06:00:00-GST-001  2022-02-03T06:00Z
# 9   2022-03-13T12:00:00-GST-001  2022-03-13T12:00Z
# 10  2022-04-10T03:00:00-GST-001  2022-04-10T03:00Z
# 11  2022-04-14T15:00:00-GST-001  2022-04-14T15:00Z
# 12  2022-08-07T21:00:00-GST-001  2022-08-07T21:00Z
# 13  2022-08-17T18:00:00-GST-001  2022-08-17T18:00Z
# 14  2022-09-04T03:00:00-GST-001  2022-09-04T03:00Z
# 15  2022-09-27T00:00:00-GST-001  2022-09-27T00:00Z
# 16  2023-02-27T03:00:00-GST-001  2023-02-27T03:00Z
# ...

# %%
import pandas as pd


df = pd.json_normalize(data)



def extract_kp(values):
    if isinstance(values, list) and len(values) > 0:
        entry = values[0]  
        return entry.get("kpIndex", None)
    return None

def extract_kp_time(values):
    if isinstance(values, list) and len(values) > 0:
        entry = values[0]
        return entry.get("observedTime", None)
    return None

df["kpIndex"] = df["allKpIndex"].apply(extract_kp)
df["kpIndexTime"] = df["allKpIndex"].apply(extract_kp_time)


df = df.drop(columns=["allKpIndex"])


def extract_linked(values):
    if isinstance(values, list) and len(values) > 0:
        return values[0].get("activityID", None)
    return None

df["linkedEventID"] = df["linkedEvents"].apply(extract_linked)
df = df.drop(columns=["linkedEvents"])



time_cols = ["startTime", "kpIndexTime", "submissionTime"]

for col in time_cols:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col], errors="coerce")


order = [
    "gstID",
    "startTime",
    "kpIndex",
    "kpIndexTime",
    "linkedEventID",
    "link",
    "submissionTime",
]

df = df[[col for col in order if col in df.columns]]


df.head(20)
# Out:
#                           gstID                 startTime  kpIndex  \
# 0   2020-09-27T21:00:00-GST-001 2020-09-27 21:00:00+00:00      6.0
# 1   2021-03-01T03:00:00-GST-001 2021-03-01 03:00:00+00:00      6.0
# 2   2021-03-20T06:00:00-GST-001 2021-03-20 06:00:00+00:00      6.0
# 3   2021-05-12T12:00:00-GST-001 2021-05-12 12:00:00+00:00      7.0
# 4   2021-10-12T03:00:00-GST-001 2021-10-12 03:00:00+00:00      6.0
# 5   2021-11-03T21:00:00-GST-001 2021-11-03 21:00:00+00:00      7.0
# 6   2022-01-14T21:00:00-GST-001 2022-01-14 21:00:00+00:00      6.0
# 7   2022-01-19T00:00:00-GST-001 2022-01-19 00:00:00+00:00      6.0
# 8   2022-02-03T06:00:00-GST-001 2022-02-03 06:00:00+00:00      5.0
# 9   2022-03-13T12:00:00-GST-001 2022-03-13 12:00:00+00:00      6.0
# 10  2022-04-10T03:00:00-GST-001 2022-04-10 03:00:00+00:00      7.0
# 11  2022-04-14T15:00:00-GST-001 2022-04-14 15:00:00+00:00      6.0
# 12  2022-08-07T21:00:00-GST-001 2022-08-07 21:00:00+00:00      6.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt


df["kpIndexTime"] = pd.to_datetime(df["kpIndexTime"], errors="coerce")

df_kp = df.dropna(subset=["kpIndex"])


df_kp = df_kp.sort_values("kpIndexTime")


plt.figure(figsize=(12,6))
plt.plot(df_kp["kpIndexTime"], df_kp["kpIndex"], marker='o', linestyle='-', linewidth=2)

plt.title("KP Index Levels Over Time (Geomagnetic Storms)")
plt.xlabel("Date")
plt.ylabel("KP Index")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# DONKI(Coronal Mass Ejections (CME))

# %%
import pandas as pd
url = "https://api.nasa.gov/DONKI/CME"
params = {
    "api_key": api_key,
    "count": 10
}

response = requests.get(url, params=params)
data = response.json()

df = pd.json_normalize(data)
df.head()

data = response.json()
import pandas as pd

df = pd.json_normalize(data)

params = {
    "api_key": api_key,
    "count": 10
}

response = requests.get(url, params=params)
data = response.json()

df = pd.json_normalize(data)
df.head()

data = response.json()
import pandas as pd

df = pd.json_normalize(data)


params = {
    "api_key": api_key,
    "count": 10
}

response = requests.get(url, params=params)
data = response.json()

df = pd.json_normalize(data)
df.head()

data = response.json()
import pandas as pd

df = pd.json_normalize(data)

params = {
    "api_key": api_key,
    "count": 10
}

response = requests.get(url, params=params)
data = response.json()

df = pd.json_normalize(data)
df.head()

data = response.json()
import pandas as pd

df = pd.json_normalize(data)

df.to_csv("donki_CME.csv", index=False)

# %%
df.info()
df.head(30)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   activityID         177 non-null    object
#  1   catalog            177 non-null    object
#  2   startTime          177 non-null    object
#  3   instruments        177 non-null    object
#  4   sourceLocation     177 non-null    object
#  5   activeRegionNum    35 non-null     float64
#  6   note               177 non-null    object
#  7   submissionTime     177 non-null    object
#  8   versionId          177 non-null    int64
#  9   link               177 non-null    object
#  10  cmeAnalyses        177 non-null    object
#  11  linkedEvents       26 non-null     object
#  12  sentNotifications  61 non-null     object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 18.1+ KB
#                      activityID      catalog          startTime  \
# ...

# %%
import pandas as pd

df = pd.json_normalize(data)


def extract_instrument(values):
    if isinstance(values, list) and len(values) > 0:
        return values[0].get("displayName")
    return None

df["instrument"] = df["instruments"].apply(extract_instrument)
df = df.drop(columns=["instruments"])

df["sourceLocation"] = df["sourceLocation"].astype(str).str.strip()
df["activeRegionNum"] = df["activeRegionNum"]


def extract_speed(values):
    if isinstance(values, list) and len(values) > 0:
        return values[0].get("speed", None)
    return None

def extract_type(values):
    if isinstance(values, list) and len(values) > 0:
        return values[0].get("type", None)
    return None

df["cme_speed"] = df["cmeAnalyses"].apply(extract_speed)
df["cme_type"] = df["cmeAnalyses"].apply(extract_type)

df = df.drop(columns=["cmeAnalyses"])


def extract_linked(values):
    if isinstance(values, list) and len(values) > 0:
        return values[0].get("activityID", None)
    return None

df["linkedEventID"] = df["linkedEvents"].apply(extract_linked)
df = df.drop(columns=["linkedEvents"])


time_cols = ["startTime", "submissionTime"]

for col in time_cols:
    df[col] = pd.to_datetime(df[col], errors="coerce")


cols_order = [
    "activityID",
    "startTime",
    "instrument",
    "sourceLocation",
    "activeRegionNum",
    "cme_speed",
    "cme_type",
    "linkedEventID",
    "catalog",
    "note",
    "submissionTime"
]

df = df[[c for c in cols_order if c in df.columns]]


df.head(20)
# Out:
#                      activityID                 startTime  \
# 0   2025-10-26T02:12:00-CME-001 2025-10-26 02:12:00+00:00
# 1   2025-10-26T08:36:00-CME-001 2025-10-26 08:36:00+00:00
# 2   2025-10-26T16:36:00-CME-001 2025-10-26 16:36:00+00:00
# 3   2025-10-26T19:48:00-CME-001 2025-10-26 19:48:00+00:00
# 4   2025-10-26T20:36:00-CME-001 2025-10-26 20:36:00+00:00
# 5   2025-10-26T21:12:00-CME-001 2025-10-26 21:12:00+00:00
# 6   2025-10-27T03:12:00-CME-001 2025-10-27 03:12:00+00:00
# 7   2025-10-27T08:12:00-CME-001 2025-10-27 08:12:00+00:00
# 8   2025-10-27T13:09:00-CME-001 2025-10-27 13:09:00+00:00
# 9   2025-10-27T14:36:00-CME-001 2025-10-27 14:36:00+00:00
# 10  2025-10-27T17:24:00-CME-001 2025-10-27 17:24:00+00:00
# 11  2025-10-27T23:12:00-CME-001 2025-10-27 23:12:00+00:00
# 12  2025-10-28T03:24:00-CME-001 2025-10-28 03:24:00+00:00
# 13  2025-10-28T03:48:00-CME-001 2025-10-28 03:48:00+00:00
# 14  2025-10-28T08:12:00-CME-001 2025-10-28 08:12:00+00:00
# ...

# %%
df.dropna()
# Out:
#                           gstID                 startTime  kpIndex  \
# 0   2020-09-27T21:00:00-GST-001 2020-09-27 21:00:00+00:00     6.00
# 1   2021-03-01T03:00:00-GST-001 2021-03-01 03:00:00+00:00     6.00
# 2   2021-03-20T06:00:00-GST-001 2021-03-20 06:00:00+00:00     6.00
# 3   2021-05-12T12:00:00-GST-001 2021-05-12 12:00:00+00:00     7.00
# 4   2021-10-12T03:00:00-GST-001 2021-10-12 03:00:00+00:00     6.00
# 5   2021-11-03T21:00:00-GST-001 2021-11-03 21:00:00+00:00     7.00
# 6   2022-01-14T21:00:00-GST-001 2022-01-14 21:00:00+00:00     6.00
# 7   2022-01-19T00:00:00-GST-001 2022-01-19 00:00:00+00:00     6.00
# 8   2022-02-03T06:00:00-GST-001 2022-02-03 06:00:00+00:00     5.00
# 9   2022-03-13T12:00:00-GST-001 2022-03-13 12:00:00+00:00     6.00
# 10  2022-04-10T03:00:00-GST-001 2022-04-10 03:00:00+00:00     7.00
# 11  2022-04-14T15:00:00-GST-001 2022-04-14 15:00:00+00:00     6.00
# 12  2022-08-07T21:00:00-GST-001 2022-08-07 21:00:00+00:00     6.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 35 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   identifier                       10 non-null     object
#  1   caption                          10 non-null     object
#  2   image                            10 non-null     object
#  3   version                          10 non-null     object
#  4   date                             10 non-null     object
#  5   centroid_coordinates.lat         10 non-null     float64
#  6   centroid_coordinates.lon         10 non-null     float64
#  7   dscovr_j2000_position.x          10 non-null     float64
#  8   dscovr_j2000_position.y          10 non-null     float64
#  9   dscovr_j2000_position.z          10 non-null     float64
#  10  lunar_j2000_position.x           10 non-null     float64
#  11  lunar_j2000_position.y           10 non-null     float64
# ...

# %%
import pandas as pd

all_dfs = {}

for name in dir():
    try:
        obj = eval(name)
        if isinstance(obj, pd.DataFrame):
            all_dfs[name] = obj
    except:
        pass

all_dfs
# Out:
# {'_6':        identifier                                            caption  \
#  0  20250715035255  This image was taken by NASA's EPIC camera onb...
#  1  20250715045823  This image was taken by NASA's EPIC camera onb...
#  2  20250715060350  This image was taken by NASA's EPIC camera onb...
#  3  20250715070917  This image was taken by NASA's EPIC camera onb...
#  4  20250715081444  This image was taken by NASA's EPIC camera onb...
#  5  20250715092011  This image was taken by NASA's EPIC camera onb...
#  6  20250715102538  This image was taken by NASA's EPIC camera onb...
#  7  20250715113105  This image was taken by NASA's EPIC camera onb...
#  8  20250715123633  This image was taken by NASA's EPIC camera onb...
#  9  20250715134039  This image was taken by NASA's EPIC camera onb...
#
#                      image version                 date  \
#  0  epic_1b_20250715035255      03  2025-07-15 03:48:07
#  1  epic_1b_20250715045823      03  2025-07-15 04:53:34
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your file (replace with your filename if needed)
df = pd.read_csv("/Users/jussaragaspar/Downloads/neo_90days.csv")

# Plot: Miss Distance vs Velocity
plt.figure(figsize=(10,6))

plt.scatter(
    df["miss_distance_km"],
    df["relative_velocity_km_s"],
    alpha=0.7,
    marker="x"
)

# Set orange color AFTER drawing
plt.setp(plt.gca().collections[0], color="orange")

plt.title("Asteroid Miss Distance vs Velocity")
plt.xlabel("Miss Distance (km)")
plt.ylabel("Velocity (km/s)")
plt.grid(True)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("/Users/jussaragaspar/Downloads/neo_90days.csv")

df["close_approach_date"] = pd.to_datetime(df["close_approach_date"], errors="coerce")

events_per_day = df.groupby(df["close_approach_date"].dt.date).size()

plt.figure(figsize=(12,6))
plt.plot(
    events_per_day.index,
    events_per_day.values,
    marker='o',
    color='orange',
    linewidth=2
)

plt.title("Number of NEO Asteroid Events per Day")
plt.xlabel("Date of Close Approach")
plt.ylabel("Asteroid Count")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df.columns.tolist()
# Out:
# ['name',
#  'id',
#  'hazardous',
#  'close_approach_date',
#  'miss_distance_km',
#  'relative_velocity_km_s',
#  'diameter_min_m',
#  'diameter_max_m']

# %%
df["diameter_min_m"] = pd.to_numeric(df["diameter_min_m"], errors="coerce")
df["diameter_max_m"] = pd.to_numeric(df["diameter_max_m"], errors="coerce")
df["diameter_avg_m"] = (df["diameter_min_m"] + df["diameter_max_m"]) / 2
df["diameter_avg_km"] = df["diameter_avg_m"] / 1000

# %%
plt.figure(figsize=(10,6))
plt.hist(df["diameter_avg_m"].dropna(), bins=20, color="orange")
plt.title("Distribution of Asteroid Diameters (meters)")
plt.xlabel("Diameter (m)")
plt.ylabel("Count")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(df["diameter_avg_km"].dropna(), bins=20, color="orange")
plt.title("Distribution of Asteroid Diameters (km)")
plt.xlabel("Diameter (km)")
plt.ylabel("Count")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.hist(df["diameter_avg_m"], bins=20, color="orange")
plt.title("Distribution of Asteroid Diameters (m)")
plt.xlabel("Diameter (m)")
plt.ylabel("Count")
plt.grid(True)
plt.show()
